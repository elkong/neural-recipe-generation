# %% [markdown]
# # GRU
#
# Use [TensorFlow](https://www.tensorflow.org/tutorials/text/text_generation) to train a word level GRU on the preprocessed Recipe Box dataset.
#
# The output of this model will be a dataset of title+ingredients text files, the premise-generating (first) step of our hierarchical generation system whose elaboration (second) step is our Checklist model.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import pathlib
import os
import re

from tqdm import tqdm
tqdm.pandas()
# Out:
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
CACHE_DIR = './drive/Shared drives/Capstone/tmp'
pathlib.Path(CACHE_DIR).mkdir(exist_ok=True)
dataset_path = os.path.join(CACHE_DIR, 'emoji_text_recipes.pkl')

# %%
if not os.path.exists(dataset_path):
    raise SystemExit("Run preprocess_rnn_word.ipynb to generate data file before continuing")
else:
    recipes = pd.read_pickle(dataset_path)

# %%
recipes.head()
# Out:
# 0    🍴 Slow Cooker Chicken and Dumplings\n\n🥑\n• 4 ...
# 1    🍴 Awesome Slow Cooker Pot Roast\n\n🥑\n• 2 (10....
# 2    🍴 Brown Sugar Meatloaf\n\n🥑\n• 1/2 cup packed ...
# 3    🍴 Best Chocolate Chip Cookies\n\n🥑\n• 1 cup bu...
# 4    🍴 Homemade Mac and Cheese Casserole\n\n🥑\n• 8 ...
# dtype: object

# %% [markdown]
# ### Strip off instructions, so as to only predict ingredients.

# %%
def strip_off_instrs(recipe):
    return recipe.split('🥣')[0]

recipes = recipes.apply(lambda recipe: strip_off_instrs(recipe))

# %%
recipes[0]
# Out:
# '🍴 Slow Cooker Chicken and Dumplings\n\n🥑\n• 4 skinless, boneless chicken breast halves\n• 2 tablespoons butter\n• 2 (10.75 ounce) cans condensed cream of chicken soup\n• 1 onion, finely diced\n• 2 (10 ounce) packages refrigerated biscuit dough, torn into pieces\n\n'

# %% [markdown]
# ## Vectorize the text

# %%
# This makes the dataset tiny
# recipes = recipes[:100]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
to_exclude = '#$&*/<=>@[\\]^_`{|}~\t'
to_tokenize = '.,:;!?"-+()%\'\n'

def separate_punct(text):
    return re.sub(r'(['+to_tokenize+'])', r' \1 ', text)

recipes = recipes.progress_apply(lambda recipe: separate_punct(recipe))
# Out:
# 100%|██████████| 105789/105789 [00:02<00:00, 36294.19it/s]

# %%
# tokenizer = Tokenizer(char_level=False, filters='', lower=False, split=' ', oov_token='<UNK>')
tokenizer = Tokenizer(char_level=False, filters=to_exclude, lower=True, split=' ', oov_token='<UNK>')
tokenizer.fit_on_texts(recipes)

# %%
encoded_recipes = tokenizer.texts_to_sequences(recipes)

# %%
encoded_recipes[0]
# Out:
# [11,
#  677,
#  714,
#  46,
#  16,
#  1360,
#  2,
#  2,
#  12,
#  2,
#  3,
#  8,
#  219,
#  6,
#  175,
#  46,
#  231,
#  288,
#  2,
#  3,
#  5,
#  15,
#  27,
#  2,
#  3,
#  5,
#  13,
#  122,
#  68,
#  398,
#  31,
#  14,
#  205,
#  322,
#  44,
#  74,
#  46,
#  159,
#  2,
#  3,
#  4,
#  42,
#  6,
#  58,
#  59,
#  2,
#  3,
#  5,
#  13,
#  122,
#  31,
#  14,
#  347,
#  578,
#  1261,
#  424,
#  6,
#  367,
#  43,
#  99,
#  2,
#  2]

# %%
recipe_maxlen = max([len(r) for r in encoded_recipes])
recipe_maxlen
# Out:
# 336

# %%
padded_recipes = pad_sequences(encoded_recipes,
                               padding='post',
                               truncating='post',
                               maxlen=recipe_maxlen+1) # Guarantee at least 1 padding character at end

# %%
padded_recipes
# Out:
# array([[  11,  677,  714, ...,    0,    0,    0],
#        [  11, 2312,  677, ...,    0,    0,    0],
#        [  11,   93,   26, ...,    0,    0,    0],
#        ...,
#        [  11,  280,  484, ...,    0,    0,    0],
#        [  11,   87,  178, ...,    0,    0,    0],
#        [  11, 4650, 1915, ...,    0,    0,    0]], dtype=int32)

# %%
vocab_size = len(tokenizer.word_counts) + 2
idx2word = tokenizer.sequences_to_texts([[idx] for idx in range(vocab_size)])

# %%
idx2word
# Out:
# ['<UNK>',
#  '<UNK>',
#  '\n',
#  '•',
#  '1',
#  '2',
#  ',',
#  'cup',
#  '4',
#  'teaspoon',
#  '3',
#  '🍴',
#  '🥑',
#  '(',
#  ')',
#  'tablespoons',
#  'and',
#  'chopped',
#  'cups',
#  'salt',
#  'pepper',
#  'ground',
#  'tablespoon',
#  'fresh',
#  'oil',
#  'or',
#  'sugar',
#  'butter',
#  'to',
#  'garlic',
#  'black',
#  'ounce',
#  'teaspoons',
#  'sliced',
#  'white',
#  'ounces',
#  'olive',
#  '8',
#  'cheese',
#  'for',
#  'red',
#  'large',
#  'onion',
#  'into',
#  'cream',
#  'with',
#  'chicken',
#  'freshly',
#  'sauce',
#  'pound',
#  'cut',
#  'juice',
#  'flour',
#  '6',
#  'minced',
#  'lemon',
#  'water',
#  'taste',
#  'finely',
#  'diced',
#  'peeled',
#  'powder',
#  'leaves',
#  'cloves',
#  'can',
#  'grated',
#  'milk',
#  'green',
#  '.',
#  'all-purpose',
#  'kosher',
#  'eggs',
#  'dried',
#  "'",
#  'of',
#  'vanilla',
#  'pounds',
#  '5',
#  'small',
#  'vinegar',
#  'vegetable',
#  'about',
#  'egg',
#  'tomatoes',
#  'plus',
#  'baking',
#  'as',
#  'chocolate',
#  'extract',
#  'thinly',
#  'unsalted',
#  'package',
#  'wine',
#  'brown',
#  'slices',
#  'parsley',
#  'shredded',
#  'whole',
#  'drained',
#  'pieces',
#  'bread',
#  'medium',
#  'cinnamon',
#  '12',
#  ':',
#  'orange',
#  'in',
#  'optional',
#  'rice',
#  's',
#  'pinch',
#  'dry',
#  'lime',
#  'salad',
#  'extra-virgin',
#  'potatoes',
#  'mustard',
#  'more',
#  'beef',
#  'onions',
#  'tomato',
#  'frozen',
#  '10',
#  'garnish',
#  'bell',
#  'such',
#  'ginger',
#  'crushed',
#  'hot',
#  'corn',
#  'a',
#  'beans',
#  'seeded',
#  'cilantro',
#  'sweet',
#  'halved',
#  'basil',
#  'seeds',
#  'broth',
#  'celery',
#  'honey',
#  'heavy',
#  'parmesan',
#  'packed',
#  'the',
#  'thyme',
#  'softened',
#  'pork',
#  'divided',
#  'ice',
#  'soda',
#  'yellow',
#  'cooked',
#  'sour',
#  'peppers',
#  'bacon',
#  'melted',
#  'apple',
#  'clove',
#  'soup',
#  'coarsely',
#  'toasted',
#  '2-inch',
#  'roasted',
#  'chili',
#  '16',
#  'coconut',
#  'cubes',
#  'mushrooms',
#  'soy',
#  'recipe',
#  'mix',
#  'zest',
#  'beaten',
#  'mayonnaise',
#  'boneless',
#  'cumin',
#  'syrup',
#  'cake',
#  'cheddar',
#  'carrots',
#  'light',
#  'stock',
#  'stick',
#  'shrimp',
#  'italian',
#  'removed',
#  'cayenne',
#  'chips',
#  'serving',
#  'pie',
#  'seasoning',
#  'bunch',
#  'room',
#  'temperature',
#  'mint',
#  'trimmed',
#  'oregano',
#  'chile',
#  'flakes',
#  'peanut',
#  'rinsed',
#  '15',
#  'inch',
#  'sprigs',
#  'cans',
#  'pasta',
#  '14',
#  'paprika',
#  'sesame',
#  'potato',
#  'follows',
#  'nutmeg',
#  'thawed',
#  'juiced',
#  'at',
#  'crumbled',
#  'needed',
#  'pitted',
#  'skinless',
#  'from',
#  'thin',
#  'spinach',
#  'thick',
#  'sea',
#  'paste',
#  'bay',
#  'grilled',
#  '1-inch',
#  'dijon',
#  'dark',
#  'breast',
#  'cubed',
#  'pineapple',
#  'strips',
#  'quartered',
#  'confectioners',
#  'turkey',
#  'yogurt',
#  'baby',
#  'rosemary',
#  'cooking',
#  'one',
#  'sausage',
#  'crumbs',
#  'smoked',
#  'scallions',
#  'canola',
#  'head',
#  'recommended',
#  'cored',
#  'unsweetened',
#  'cold',
#  'cookies',
#  'walnuts',
#  '4-inch',
#  '-',
#  'olives',
#  'almonds',
#  'granulated',
#  'lengthwise',
#  'chives',
#  'ripe',
#  'cider',
#  'worcestershire',
#  'pumpkin',
#  'jalapeno',
#  'spray',
#  'lettuce',
#  'sticks',
#  'oz',
#  'canned',
#  'wedges',
#  'balsamic',
#  'dill',
#  'on',
#  'fluid',
#  'salmon',
#  'cherry',
#  'dressing',
#  'zucchini',
#  'peas',
#  'bean',
#  'lightly',
#  'steak',
#  'carrot',
#  'mozzarella',
#  'cornstarch',
#  'halves',
#  'buttermilk',
#  'ham',
#  'each',
#  'half',
#  'prepared',
#  'spicy',
#  'roughly',
#  'chunks',
#  '7',
#  'pecans',
#  'frying',
#  'shallots',
#  'cocoa',
#  'raisins',
#  'pure',
#  'fillets',
#  'topping',
#  'almond',
#  'cucumber',
#  'chilled',
#  'if',
#  'strawberries',
#  'cabbage',
#  'whipped',
#  'jar',
#  'coarse',
#  'rum',
#  '"',
#  'salsa',
#  'apples',
#  'squash',
#  'leaf',
#  'fine',
#  'condensed',
#  'extra',
#  'broccoli',
#  '9',
#  'mixed',
#  'fennel',
#  'plain',
#  'maple',
#  'stalks',
#  'yolks',
#  'stems',
#  'pint',
#  'liqueur',
#  'curry',
#  'semisweet',
#  'fish',
#  'greens',
#  'banana',
#  'coriander',
#  'baked',
#  'french',
#  'flat-leaf',
#  'wheat',
#  '25',
#  'bottle',
#  'packages',
#  'avocado',
#  'chiles',
#  'preferably',
#  'whipping',
#  'mushroom',
#  'mango',
#  'fruit',
#  'whites',
#  'sherry',
#  'plum',
#  'dice',
#  'nuts',
#  'shortening',
#  'meat',
#  'oats',
#  'ketchup',
#  'shallot',
#  'cracked',
#  'split',
#  'torn',
#  'deveined',
#  'crust',
#  'warm',
#  'washed',
#  'pudding',
#  'noodles',
#  'asparagus',
#  'squeezed',
#  'mashed',
#  'blue',
#  'chops',
#  'very',
#  'feta',
#  'sage',
#  'sweetened',
#  'ribs',
#  'coffee',
#  'roast',
#  '20',
#  'creamy',
#  'tortillas',
#  'arugula',
#  'other',
#  'breasts',
#  'low-sodium',
#  'lamb',
#  'instant',
#  'beer',
#  'de',
#  'vodka',
#  '75',
#  'seed',
#  'pizza',
#  'chipotle',
#  'piece',
#  'container',
#  'goat',
#  'cranberry',
#  'peppercorns',
#  'dash',
#  'tarragon',
#  'tsp',
#  'golden',
#  'margarine',
#  'powdered',
#  'quart',
#  'fried',
#  'peel',
#  'pan',
#  'zested',
#  'spice',
#  'spaghetti',
#  'tuna',
#  '8-ounce',
#  'cranberries',
#  'rolls',
#  'dough',
#  'lemons',
#  'jack',
#  'uncooked',
#  'ricotta',
#  'food',
#  'strawberry',
#  '24',
#  'puree',
#  'cherries',
#  'capers',
#  'easy',
#  '18',
#  'cornmeal',
#  'not',
#  '15-ounce',
#  'allspice',
#  'seasoned',
#  'pastry',
#  'julienned',
#  'fat',
#  'vinaigrette',
#  'cleaned',
#  'loaf',
#  'bananas',
#  'root',
#  'bag',
#  'mexican',
#  'dip',
#  'skin',
#  'blueberries',
#  'limes',
#  'stemmed',
#  'raspberry',
#  'raw',
#  'raspberries',
#  'greek',
#  'lean',
#  'all',
#  'tea',
#  'reserved',
#  'i',
#  'dusting',
#  'asian',
#  'yeast',
#  'crosswise',
#  'good',
#  'parts',
#  'half-and-half',
#  'separated',
#  'only',
#  'horseradish',
#  'sandwich',
#  'smashed',
#  'boiling',
#  'virgin',
#  'quarts',
#  'homemade',
#  'molasses',
#  'salted',
#  'stuffed',
#  'tbsp',
#  'cauliflower',
#  'steaks',
#  'crackers',
#  'swiss',
#  'peach',
#  ';',
#  'flavored',
#  'crab',
#  'ii',
#  'florets',
#  'romaine',
#  'pine',
#  'thai',
#  'casserole',
#  'brandy',
#  'peaches',
#  'spanish',
#  's®',
#  'oranges',
#  'kale',
#  'rolled',
#  '12-ounce',
#  'rounds',
#  'well',
#  '6-ounce',
#  'pickled',
#  'lb',
#  'sifted',
#  'box',
#  'long',
#  'drizzling',
#  'eggplant',
#  'creme',
#  'soft',
#  'g',
#  'sharp',
#  'blend',
#  'pesto',
#  'stew',
#  'see',
#  'peanuts',
#  'cocktail',
#  'grape',
#  'vegetables',
#  'flaked',
#  'prosciutto',
#  'mini',
#  'russet',
#  'desired',
#  'sprouts',
#  'two',
#  'seedless',
#  'kernels',
#  'liquid',
#  'pecan',
#  'hearts',
#  'quick',
#  'graham',
#  'caramel',
#  'round',
#  'simple',
#  'turmeric',
#  'artichoke',
#  'bittersweet',
#  'purpose',
#  'granny',
#  'low-fat',
#  'bunches',
#  'wild',
#  'smith',
#  'tenderloin',
#  'champagne',
#  'gold',
#  'sprig',
#  'handful',
#  'scallops',
#  'shelled',
#  'cardamom',
#  'serrano',
#  'your',
#  'stalk',
#  'thighs',
#  'english',
#  '10-ounce',
#  'bite-size',
#  'buns',
#  'nonstick',
#  'pear',
#  'monterey',
#  'blanched',
#  'tofu',
#  'heads',
#  'refrigerated',
#  'bars',
#  'bourbon',
#  'herb',
#  'bbq',
#  'butternut',
#  'squares',
#  'rings',
#  'adobo',
#  'old',
#  'spiced',
#  'jam',
#  'baguette',
#  'new',
#  'tortilla',
#  '2-ounce',
#  'walnut',
#  'slice',
#  'frosting',
#  '4-ounce',
#  '5-ounce',
#  'macaroni',
#  'available',
#  'filling',
#  'pears',
#  '14-ounce',
#  'bouillon',
#  'panko',
#  'cereal',
#  'veal',
#  'evaporated',
#  'breadcrumbs',
#  'broken',
#  'sun-dried',
#  'shells',
#  'ears',
#  'quinoa',
#  'grain',
#  'by',
#  'firm',
#  'apricot',
#  'muffins',
#  'berries',
#  'ml',
#  'watermelon',
#  'grapes',
#  'brushing',
#  'penne',
#  'active',
#  'chinese',
#  'scrubbed',
#  'couscous',
#  'crispy',
#  'tequila',
#  'cracker',
#  '16-ounce',
#  'relish',
#  'candy',
#  'note',
#  'pomegranate',
#  'lobster',
#  'leeks',
#  'loin',
#  'yukon',
#  'yolk',
#  'cooled',
#  'an',
#  'soaked',
#  'watercress',
#  'scallion',
#  'parmigiano-reggiano',
#  'slivered',
#  'roma',
#  'shiitake',
#  'wings',
#  'clams',
#  'degrees',
#  'store-bought',
#  '1-ounce',
#  'cucumbers',
#  'kalamata',
#  'avocados',
#  'rib',
#  'bone-in',
#  '11',
#  'dashes',
#  'cookie',
#  'japanese',
#  'gin',
#  'inches',
#  'unpeeled',
#  'grapefruit',
#  '28-ounce',
#  'taco',
#  'style',
#  'marinated',
#  'herbs',
#  'sandwiches',
#  'equipment',
#  'slow',
#  'mild',
#  'picked',
#  'beets',
#  'crabmeat',
#  'skewers',
#  'blueberry',
#  'fillet',
#  'discarded',
#  'chip',
#  'additional',
#  'tart',
#  'chorizo',
#  'tartar',
#  'special',
#  'preserves',
#  'stuffing',
#  '28',
#  'kidney',
#  'puff',
#  'marshmallows',
#  'gelatin',
#  'it',
#  'cook',
#  'coloring',
#  'part',
#  'anise',
#  'romano',
#  'anchovy',
#  'sheets',
#  'saffron',
#  'oyster',
#  'greasing',
#  'spread',
#  'oatmeal',
#  'dipping',
#  'chuck',
#  'cooker',
#  'drops',
#  'breakfast',
#  'pancetta',
#  'best',
#  'crisp',
#  'distilled',
#  'apricots',
#  'firmly',
#  '30',
#  'pickle',
#  'espresso',
#  'any',
#  'bulb',
#  'regular',
#  'sprinkling',
#  'glaze',
#  'applesauce',
#  'sauteed',
#  'cakes',
#  'shaved',
#  'nonfat',
#  'shell',
#  'candied',
#  'concentrate',
#  'whole-wheat',
#  'mascarpone',
#  'portobello',
#  'sirloin',
#  'hulled',
#  'chickpeas',
#  '%',
#  'superfine',
#  'radishes',
#  'ancho',
#  'pita',
#  'over',
#  'accompaniment',
#  'assorted',
#  'dates',
#  'slightly',
#  'favorite',
#  'toast',
#  'maraschino',
#  '3-inch',
#  'club',
#  'slaw',
#  'ranch',
#  'burgers',
#  'original',
#  'barbecue',
#  'cajun',
#  'steamed',
#  'use',
#  'pancakes',
#  'halibut',
#  'fat-free',
#  'gravy',
#  'lentils',
#  'grapeseed',
#  '4-inch-thick',
#  'pecorino',
#  'vermouth',
#  'fudge',
#  'summer',
#  'whiskey',
#  'duck',
#  'poblano',
#  'flat',
#  'julienne',
#  'mussels',
#  'pink',
#  'brussels',
#  'gruyere',
#  'shoulder',
#  'seafood',
#  'nectar',
#  'roll',
#  'polenta',
#  'jumbo',
#  'size',
#  'organic',
#  'grams',
#  'crusty',
#  'hazelnuts',
#  'linguine',
#  'loosely',
#  'you',
#  'spring',
#  'boiled',
#  'clam',
#  '2-pound',
#  'chilies',
#  'leek',
#  'sparkling',
#  'dish',
#  'pea',
#  'smoothie',
#  'substitute',
#  'four',
#  'splash',
#  'cheesecake',
#  'fraiche',
#  'low-salt',
#  'top',
#  'gorgonzola',
#  'total',
#  '8-inch',
#  'blackberries',
#  'figs',
#  'jalapenos',
#  'tops',
#  '32',
#  'reduced-sodium',
#  'orzo',
#  'hamburger',
#  'patted',
#  '2-inch-thick',
#  'pints',
#  'cornbread',
#  'biscuits',
#  'chutney',
#  'irish',
#  'rhubarb',
#  'provolone',
#  'country',
#  'bottled',
#  'cod',
#  'balls',
#  'citrus',
#  'melon',
#  'garbanzo',
#  'brewed',
#  'lasagna',
#  'miniature',
#  'berry',
#  'some',
#  'agave',
#  'leftover',
#  'whole-grain',
#  'long-grain',
#  'jelly',
#  'natural',
#  'like',
#  'free',
#  'grill',
#  'pickles',
#  'until',
#  'star',
#  'lemonade',
#  'cannellini',
#  'flank',
#  'quality',
#  'rind',
#  'few',
#  'sheet',
#  'gluten-free',
#  'angel',
#  'bags',
#  'sourdough',
#  'meatballs',
#  'popcorn',
#  'then',
#  'crisco®',
#  'tabasco',
#  'undrained',
#  'reduced-fat',
#  'no',
#  'marjoram',
#  'beet',
#  'packet',
#  'pistachios',
#  'glazed',
#  'iceberg',
#  'pot',
#  'triple',
#  'cupcakes',
#  'short',
#  'oysters',
#  'warmed',
#  'rye',
#  'bass',
#  'snapper',
#  'sriracha',
#  'old-fashioned',
#  'american',
#  'self-rising',
#  '13',
#  'vidalia',
#  'fries',
#  'punch',
#  'minutes',
#  'bitters',
#  'eyeball',
#  'classic',
#  'cheesy',
#  'barbeque',
#  'bits',
#  'hoisin',
#  'poppy',
#  'crusts',
#  'chestnuts',
#  'f',
#  'nut',
#  'radicchio',
#  'tails',
#  'cashews',
#  'sunflower',
#  'deli',
#  'buffalo',
#  'marinara',
#  'gallon',
#  'braised',
#  '1-pound',
#  'but',
#  'endive',
#  'habanero',
#  'delicious',
#  'hash',
#  'brownies',
#  'italian-style',
#  'flavor',
#  'marinade',
#  'button',
#  'hazelnut',
#  'artichokes',
#  'wedge',
#  'double',
#  'is',
#  'cottage',
#  'bottles',
#  'chard',
#  'heaping',
#  'caraway',
#  'snow',
#  'port',
#  'paper',
#  'jalapeño',
#  'stewed',
#  'masala',
#  'tacos',
#  'pinto',
#  'pressed',
#  'skinned',
#  'rub',
#  'tender',
#  'iii',
#  'peppermint',
#  'pods',
#  'pearl',
#  'percent',
#  'unbleached',
#  'burger',
#  'hard',
#  'c',
#  'aged',
#  'bones',
#  'low',
#  'truffle',
#  'grits',
#  'poached',
#  'deep',
#  'elbow',
#  'vegan',
#  'wrappers',
#  'kernel',
#  'croutons',
#  'ends',
#  'grand',
#  'tbs',
#  'approximately',
#  'sorbet',
#  'teriyaki',
#  'lump',
#  'bake',
#  'spears',
#  'miso',
#  'snap',
#  'caramelized',
#  'chunky',
#  'links',
#  'brisket',
#  'butterscotch',
#  'ale',
#  'quarters',
#  'cube',
#  ...]

# %%
idx2word[1]
# Out:
# '<UNK>'

# %%
print(vocab_size)
print(len(padded_recipes))
# Out:
# 32179
# 105789

# %% [markdown]
# # Create training examples and targets

# %%
dataset = tf.data.Dataset.from_tensor_slices(padded_recipes)

# %%
# For each sequence, duplicate and shift it to form the input and target text
def split_input_target(recipe):
    input_text = recipe[:-1]
    target_text = recipe[1:]
    return input_text, target_text

dataset = dataset.map(split_input_target)

# %%
BATCH_SIZE = 1 # ONLINE LEARNING NOW - I hope this works
BUFFER_SIZE = 1000  # Buffer size to shuffle the dataset

# Create training batches
dataset = dataset \
    .shuffle(BUFFER_SIZE) \
    .batch(BATCH_SIZE, drop_remainder=True) \
    .repeat() # Repeat to have enough data during training

# %% [markdown]
# # Build the model

# %%
def build_model(vocab_size, embed_dim, rnn_units, batch_size):
    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, embed_dim, batch_input_shape=[batch_size, None]),
        tf.keras.layers.GRU(
            rnn_units,
            return_sequences=True,
            stateful=True,
            recurrent_initializer='glorot_uniform'
        ),
        tf.keras.layers.Dense(vocab_size)
    ])

    return model

# %%
EMBED_DIM = 256
RNN_UNITS = 512
MODEL_NAME = "rnn_word_punct_emoji_ingr_online"

# %%
model = build_model(
    vocab_size=vocab_size,
    embed_dim=EMBED_DIM,
    rnn_units=RNN_UNITS,
    batch_size=BATCH_SIZE)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (1, None, 256)            8237824
# _________________________________________________________________
# gru (GRU)                    (1, None, 512)            1182720
# _________________________________________________________________
# dense (Dense)                (1, None, 32179)          16507827
# =================================================================
# Total params: 25,928,371
# Trainable params: 25,928,371
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-27-32b548d8b93f> in <module>()
#       1 from keras.utils.vis_utils import plot_model
# ----> 2 plot_model(model, show_shapes=True)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/vis_utils.py in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi)
#     328       rankdir=rankdir,
#     329       expand_nested=expand_nested,
# --> 330       dpi=dpi)
#     331   to_file = path_to_string(to_file)
#     332   if dot is None:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/vis_utils.py in model_to_dot(model, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, subgraph)
#     237           inbound_layer_id = str(id(inbound_layer))
#     238           if not expand_nested:
# --> 239             assert dot.get_node(inbound_layer_id)
#     240             assert dot.get_node(layer_id)
#     241             add_edge(dot, inbound_layer_id, layer_id)
#
# AssertionError:

# %%
for input_example_batch, target_example_batch in dataset.take(1):
    example_batch_predictions = model(input_example_batch)
    print(example_batch_predictions.shape) # (batch_size, sequence_length, vocab_size)
# Out:
# (1, 336, 32179)

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)
    
example_batch_loss = loss(target_example_batch, example_batch_predictions)
prediction_shape = example_batch_predictions.shape
scalar_loss = example_batch_loss.numpy().mean()
print("Prediction shape: ", prediction_shape)
print("scalar_loss:      ", scalar_loss)
print("exp(scalar_loss): ", np.exp(scalar_loss))
print("vocab size      : ", vocab_size)
print("If all went right, exp(scalar loss) should be approximately equal to vocab size")
# Out:
# Prediction shape:  (1, 336, 32179)
# scalar_loss:       10.376923
# exp(scalar_loss):  32109.994
# vocab size      :  32179
# If all went right, exp(scalar loss) should be approximately equal to vocab size

# %%
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    patience=5,
    monitor='loss',
    restore_best_weights=True,
    verbose=1
)

# %%
# Create a checkpoints directory.
checkpoint_dir = os.path.join(CACHE_DIR, MODEL_NAME)
os.makedirs(checkpoint_dir, exist_ok=True)

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=os.path.join(checkpoint_dir, 'ckpt_{epoch}'),
    save_weights_only=True
)

# %%
def restore_checkpoint(model):
    latest_checkpoint_path = tf.train.latest_checkpoint(checkpoint_dir)

    if not latest_checkpoint_path:
        print('Checkpoint not found')
        return model, 0

    print("Checkpoint found")
    print('Path:', latest_checkpoint_path)

    model.load_weights(latest_checkpoint_path)

    latest_checkpoint_name = os.path.split(latest_checkpoint_path)[-1]
    print('Name:', latest_checkpoint_name)

    latest_epoch = latest_checkpoint_name.split('_')[-1]
    print('Epoch:', latest_epoch)

    return model, int(latest_epoch)

# %%
TOTAL_EPOCHS = 10
STEPS_PER_EPOCH = 1500

model, initial_epoch = restore_checkpoint(model)
# Out:
# Checkpoint not found

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=loss
)

# %% [markdown]
# ## Train model

# %%
history = model.fit(
    x=dataset,
    epochs=TOTAL_EPOCHS,
    steps_per_epoch=STEPS_PER_EPOCH,
    initial_epoch=initial_epoch,
    verbose=True,
    callbacks=[
        checkpoint_callback,
        early_stopping_callback
    ]
)

# Saving the trained model to file (to be able to re-use it later).
model_name = os.path.join(CACHE_DIR, MODEL_NAME, f'{MODEL_NAME}.h5')
model.save(model_name, save_format='h5')
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 150s 99ms/step - loss: 1.1489
# Epoch 2/10
# 1500/1500 [==============================] - 149s 99ms/step - loss: 0.8448
# Epoch 3/10
# 1500/1500 [==============================] - 149s 99ms/step - loss: 0.7826
# Epoch 4/10
# 1500/1500 [==============================] - 148s 99ms/step - loss: 0.5376
# Epoch 5/10
# 1500/1500 [==============================] - 149s 99ms/step - loss: 0.4858
# Epoch 6/10
# 1500/1500 [==============================] - 148s 99ms/step - loss: 0.4646
# Epoch 7/10
# 1500/1500 [==============================] - 147s 98ms/step - loss: 0.4595
# Epoch 8/10
# 1500/1500 [==============================] - 148s 99ms/step - loss: 0.4530
# Epoch 9/10
# 1500/1500 [==============================] - 148s 99ms/step - loss: 0.4571
# Epoch 10/10
# 1500/1500 [==============================] - 147s 98ms/step - loss: 0.4569

# %% [markdown]
# # Predictions

# %%
def generate_recipe(model, start_string, num_generate=1000, temperature=0.8):
    TITLE_START = "🍴 "
    # Evaluation step (generating text using the learned model)

    padded_start_string = TITLE_START + start_string

    # Converting our start string to numbers (vectorizing).
    input_eval = np.array(tokenizer.texts_to_sequences([padded_start_string]))

    # Empty string to store our results.
    text_generated = []

    # Here batch size == 1
    model.reset_states()
    for i in range(num_generate):
        predictions = model(input_eval)
        # remove the batch dimension
        predictions = tf.squeeze(predictions, 0)

        # using a categorical distribution to predict the token returned by the model
        predictions = predictions / temperature

        predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()

        if predicted_id == 0: # stop if we start generating the padding token
            break

        # Pass the predicted word as the next input to the model
        # along with the previous hidden state
        input_eval = tf.expand_dims([predicted_id], 0)

        text_generated.append(idx2word[predicted_id])

    return (padded_start_string + ' '.join(text_generated))

# %%
# Restore latest checkpoint and change batch to 1
model = build_model(vocab_size, EMBED_DIM, RNN_UNITS, batch_size=1)
model, _ = restore_checkpoint(model)
model.build(tf.TensorShape([1, None]))
# Out:
# Checkpoint found
# Path: ./drive/Shared drives/Capstone/tmp/rnn_word_punct_emoji_ingr_online/ckpt_10
# Name: ckpt_10
# Epoch: 10

# %%
generated_text = generate_recipe(model, start_string="Slow Cooked Chicken 🥑", num_generate=500, temperature=0.7)
print(generated_text)
# Out:
# 🍴 Slow Cooked Chicken 🥑
#  • 7 8 cup brown sugar
#  • 1 tablespoon butter
#  • 1 teaspoon salt
#  • 1 dash salt
#  • 1 tablespoon milk powder
#  • 1 4 teaspoon salt
#  • 1 2 teaspoon ground cinnamon
#  • salt and pepper to taste
#  • 2 tablespoons all-purpose flour
#  • 3 tablespoons all-purpose flour
#  • 1 teaspoon baking powder
#  • 1 teaspoon baking powder
#  • 1 teaspoon baking soda
#  • 1 ( 8 ounce ) package cream cheese , softened
#  • 1 teaspoon vanilla extract
#  • 1 cup all-purpose flour
#  • 1 4 cup shredded mozzarella cheese
#  • 1 ( 14 . 5 ounce ) can condensed cream of mushroom soup
#  • 1 tablespoon chopped fresh parsley
#  • 1 tablespoon lemon juice
#  • 1 tablespoon crunchy monkey , chopped
#  • 1 tablespoon chopped fresh parsley
#  • 1 tablespoon chopped onion
#  • 1 tablespoon grated parmesan cheese
#  • 1 ( 14 . 5 ounce ) can creamed corn , drained and chopped
#  • 1 pinch salt , or to taste
#  • 1 teaspoon onion powder
#  • 1 teaspoon garlic powder
#  • 1 4 teaspoon garlic powder
#  • 1 teaspoon garlic powder
#  • 1 pinch salt and pepper
#  • 1 2 cup raisins
#  • 1 cup sour cream pie

# %% [markdown]
# # Generate evaluation recipes

# %%
# Set to True for generating recipes for evaluation
GENERATE_EVAL_RECIPES = True

# %%
import random
from tqdm import tqdm

if GENERATE_EVAL_RECIPES:
    col_recipes = pd.read_pickle('/content/drive/Shared drives/Capstone/tmp/recipes.pkl')
    recipe_titles = col_recipes.filter(['title']).values.ravel().tolist()
    # recipe_words = set()

    # Create vocabulary of words used in recipe titles as potential inputs for generation
    # for title in recipe_titles:
    #     for word in title.split(' '):
    #         if len(word) > 0: # Don't add empty string
    #             recipe_words.add(word)

    eval_output_dir = os.path.join(CACHE_DIR, "rnn_word_punct_emoji_online_title_prompt_ingrs")
    pathlib.Path(eval_output_dir).mkdir(exist_ok=True)
    
    # Generate N recipes using random title as input to model
    N = 500
    used_titles = []

    for i in tqdm(range(N)):
        keyword = random.choice(tuple(recipe_titles))
        used_titles.append(keyword)
        output_file_name = os.path.join(eval_output_dir, f"rnn_word_title_ingr_{i}.txt")

        start_string = keyword + "\n\n 🥑 "

        r = generate_recipe(model, start_string=start_string, temperature=0.8)
        with open(output_file_name, 'w') as f:
            f.write(r)
    
    # Save used titles for later reference
    title_list_file = os.path.join(eval_output_dir, f"titles.txt")
    with open(title_list_file, 'w') as f:
        f.writelines("%s\n" % t for t in used_titles)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#   0%|          | 1/500 [00:00<04:48,  1.73it/s]
#   0%|          | 2/500 [00:01<05:09,  1.61it/s]
#   1%|          | 3/500 [00:02<06:23,  1.30it/s]
#   1%|          | 4/500 [00:05<12:05,  1.46s/it]
#   1%|          | 5/500 [00:07<12:39,  1.53s/it]
#   1%|          | 6/500 [00:08<11:33,  1.40s/it]
#   1%|▏         | 7/500 [00:09<11:03,  1.35s/it]
#   2%|▏         | 8/500 [00:09<08:44,  1.07s/it]
#   2%|▏         | 9/500 [00:11<09:30,  1.16s/it]
#   2%|▏         | 10/500 [00:12<09:29,  1.16s/it]
#   2%|▏         | 11/500 [00:13<09:27,  1.16s/it]
#   2%|▏         | 12/500 [00:14<07:51,  1.04it/s]
#   3%|▎         | 13/500 [00:15<08:42,  1.07s/it]
#   3%|▎         | 14/500 [00:17<10:17,  1.27s/it]
#   3%|▎         | 15/500 [00:17<08:30,  1.05s/it]
#   3%|▎         | 16/500 [00:19<09:17,  1.15s/it]
#   3%|▎         | 17/500 [00:21<11:40,  1.45s/it]
#   4%|▎         | 18/500 [00:22<12:09,  1.51s/it]
#   4%|▍         | 19/500 [00:24<12:03,  1.50s/it]
#   4%|▍         | 20/500 [00:25<10:55,  1.36s/it]
#   4%|▍         | 21/500 [00:26<09:32,  1.19s/it]
#   4%|▍         | 22/500 [00:26<07:17,  1.09it/s]
#   5%|▍         | 23/500 [00:28<10:24,  1.31s/it]
#   5%|▍         | 24/500 [00:29<08:29,  1.07s/it]
