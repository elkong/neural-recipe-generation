# %% [markdown]
# # Preprocess Checklist
#
# In this notebook we build the ingredient processing system using spaCy.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import pathlib
import os

import re
import spacy
import pickle
from collections import namedtuple

from tqdm import tqdm
tqdm.pandas()
# Out:
# /usr/local/lib/python3.7/dist-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
CACHE_DIR = './drive/Shared drives/Capstone/tmp'
pathlib.Path(CACHE_DIR).mkdir(exist_ok=True)
dataset_path = os.path.join(CACHE_DIR, 'emoji_text_recipes.pkl')

# %%
if not os.path.exists(dataset_path):
    raise SystemExit("Run preprocess_rnn_word.ipynb to generate data file before continuing")
else:
    recipes = pd.read_pickle(dataset_path)

# %%
recipes
# Out:
# 0         🍴 Slow Cooker Chicken and Dumplings\n\n🥑\n• 4 ...
# 1         🍴 Awesome Slow Cooker Pot Roast\n\n🥑\n• 2 (10....
# 2         🍴 Brown Sugar Meatloaf\n\n🥑\n• 1/2 cup packed ...
# 3         🍴 Best Chocolate Chip Cookies\n\n🥑\n• 1 cup bu...
# 4         🍴 Homemade Mac and Cheese Casserole\n\n🥑\n• 8 ...
#                                 ...
# 125158    🍴 Cream Horns\n\n🥑\n• 1 sheet frozen puff past...
# 125159    🍴 Summer Corn Salad\n\n🥑\n• 4 ears fresh corn\...
# 125160    🍴 Zucchini Stuffed Tomatoes\n\n🥑\n• 4 large pl...
# 125162    🍴 Chocolate Cake with Armagnac Ice Cream\n\n🥑\...
# 125163    🍴 Crabby Bisque\n\n🥑\n• 3 (10.5-ounce) cans re...
# Length: 105789, dtype: object

# %%
# Makes the dataset small
recipes = recipes[:20000]

# %%
recipes[0]
# Out:
# '🍴 Slow Cooker Chicken and Dumplings\n\n🥑\n• 4 skinless, boneless chicken breast halves\n• 2 tablespoons butter\n• 2 (10.75 ounce) cans condensed cream of chicken soup\n• 1 onion, finely diced\n• 2 (10 ounce) packages refrigerated biscuit dough, torn into pieces\n\n🥣\n‣ Place the chicken, butter, soup, and onion in a slow cooker, and fill with enough water to cover.\n‣ Cover, and cook for 5 to 6 hours on High. About 30 minutes before serving, place the torn biscuit dough in the slow cooker. Cook until the dough is no longer raw in the center.'

# %% [markdown]
# # Process the recipes to get the ingredients!
#
# And other operations necessary.

# %%
class IngredientProcessor(object):
  def __init__(self, use_cache=True):
    self.MEASURES = set(["tbsp", "tablespoon", "tablespoons",
            "tsp", "teaspoon", "teaspoons",
            "fl", "oz", "ounce", "ounces",
            "lb", "pound", "pounds",
            "cm", "centimeter", "centimeters", "centimetre", "centimetres",
            "inch", "inches",
            "can", "cans",
            "cup", "cups",
            "pint", "pints",
            "quart", "quarts",
            "gallon", "gallons",
            "ml", "milliliter", "millilitre", "milliliters", "millilitres",
            "l", "liter", "litre", "liters", "litres",
            "pkg", "package", "packages",
            "piece", "pieces",
            "slice", "slices",
            "small", "medium", "large",
            # "sliced", "diced", "minced", "chopped", "deveined",
            "extra"])
    self.CONTEXT_NEEDERS = set(["extract", "root", "sauce", "cream",
            "broth", "soup", "soda", "oil", "puree", "powder",
            "mix", "roast", "paste",
            "chip", "chips",
            "bean", "beans",
            "pepper", "peppers"
            "casing", "casings"])
    self.ADJECTIVES = set(['canned', 'softened', 'diced', 'chopped', 'semisweet', 'thawed', 'frozen', 'minced', 'peeled', 'seeded', 'prepared', \
                  'melted', 'pitted', 'uncooked', 'cooked', 'squeezed', 'lean', 'boneless', 'ground', 'divided', 'refrigerated', \
                  'skinless', 'crushed', 'grated', 'trimmed', 'crushed', 'sifted', 'all-purpose', 'allpurpose', 'drained', 'mashed', \
                  'rinsed', 'shredded', 'hulled', 'dry', 'dried', 'deveined', 'packed', 'fresh', 'freshly', 'sliced', 'halved', \
                  'washed', 'sweetened', 'unsweetened', 'extract', 'vegetable', 'large', 'small', 'tiny', 'fine', 'finely', 'beaten',
                  'bite-sized', 'bitesized', 'skinned', 'optional', 'toasted', 'lightly', 'loosely', 'juiced', 'cut', 'necessary', 'desired',
                  'quartered', 'slightly', 'coarsely', 'thin', 'chilled', 'scrambled', 'soft', 'hard', 'short', 'medium', 'long'] \
+ ['white', 'red', 'orange', 'yellow', 'green', 'blue', 'brown', 'black'])
    self.OTHER_PROBLEM_WORDS = set(["room", "temperature", "deep", "frying", 'if', 'to', 'into', 'taste', 'more', 'each', 'about', 'removed'])
    self.ALL_PROBLEM_WORDS = self.MEASURES.union(self.ADJECTIVES, self.OTHER_PROBLEM_WORDS)
    self.nlp = spacy.load("en_core_web_sm", disable=["textcat", "ner", "entity_ruler", "sentencizer", "merge_noun_chunks", "merge_entities", "merge_subtokens"])
    self.use_cache = use_cache
    self.cache = {}

  def deduce_core_ingredient(self, ingr_phrase):
    '''
      ingr_phrase: str
      returns: str

      Attempts to deduce a "canonical form" of the ingredient
      contained in ingr_phrase.
    '''
    words_in_phrase = ingr_phrase.split(" ")
    ingredWord = ""
    if len(words_in_phrase) >= 2 and words_in_phrase[-1].lower() in self.CONTEXT_NEEDERS:
      ingredWord = " ".join(words_in_phrase[-2:])
      # For diagnostic purposes, tell if this has happened?
      # print("DCG: ", words_in_phrase, ingredWord)
    else:
      ingredWord = words_in_phrase[-1]
    return ingredWord
  
  def cleanup_ingredient(self, ingredient):
    '''
      ingredient: str
      returns: List[str]

      Cleans up ingredient string and returns a list of ingredients
      in canonical form.
    '''
    # First clean up by removing unnecessary information
    
    # Uses regex to remove parenthesised portions and numbers,
    # https://www.kite.com/python/answers/how-to-use-regular-expressions-to-remove-text-within-parentheses-in-python
    ingredient = re.sub(r"\([^()]*\)|[0-9]|/|\.|,|'|\"", "", ingredient).lower()

    # Filter out measure words, adjectives, filler words, and other problem words
    ingredient = " ".join(word for word in ingredient.split() if not word.lower() in self.ALL_PROBLEM_WORDS)
    
    ingredient = ingredient.strip()

    if self.use_cache:
      if ingredient in self.cache:
        return self.cache[ingredient]

    # Apply spacy to get the most important noun phrase (hopefully)
    ingr_doc = self.nlp(ingredient)
    noun_phrases = [chunk.text for chunk in ingr_doc.noun_chunks]

    # Try to deduce the ingredient
    num_phrases = len(noun_phrases)
    ingr_list = ""
    if num_phrases == 0:
      # Ooh, here's a toughie.
      # If the ingredient has a ' - ', take out everything after the ' - '.
      # Same with ' and ' and ' or '
      ingredient = ingredient.split(' - ')[0].split(' and ')[0].split(' or ')[0]
      ingr_list = [ingredient] if ingredient else [] # don't add empty-string ingredients
    else:
      ingr_list = [self.deduce_core_ingredient(phrase) for phrase in noun_phrases]

    ingr_list

    if self.use_cache:
      self.cache[ingredient] = ingr_list

    return ingr_list

# %%
def flatten(lists):
  return [item for sublist in lists for item in sublist]

ProcessedRecipe = namedtuple('ProcessedRecipe', ['title', 'ingredients', 'instructions'])

IngrProc = IngredientProcessor()

def process_recipe(recipe):
  _, title, ingredients, instructions = re.split("🍴|🥑|🥣", recipe)

  # Process title
  title = title.strip()

  # Process ingredients
  ingredients = ingredients.replace('\n', '').split("•")
  ingredients = [ingredient.strip() for ingredient in ingredients if len(ingredient) > 0]
  cleaned_up_ingrs = flatten([IngrProc.cleanup_ingredient(ingredient) for ingredient in ingredients])

  # Process instructions
  instructions = instructions.replace('\n', '').split("‣")
  cleaned_up_instrs = [instruction.strip() for instruction in instructions if len(instruction) > 0]

  return ProcessedRecipe(title, cleaned_up_ingrs, cleaned_up_instrs)

def extract_title(recipe):
  _, title, _, _ = re.split("🍴|🥑|🥣", recipe)
  title = title.strip()
  return title

def extract_cleaned_ingredients(recipe):
  _, _, ingredients, _ = re.split("🍴|🥑|🥣", recipe)
  ingredients = ingredients.replace('\n', '').split("•")
  ingredients = [ingredient.strip() for ingredient in ingredients if len(ingredient) > 0]
  cleaned_up_ingrs = flatten([IngrProc.cleanup_ingredient(ingredient) for ingredient in ingredients]) 
  return cleaned_up_ingrs

def extract_cleaned_instructions(recipe):
  _, _, _, instructions = re.split("🍴|🥑|🥣", recipe)
  instructions = instructions.replace('\n', '').split("‣")
  cleaned_up_instrs = [instruction.strip() for instruction in instructions if len(instruction) > 0]
  return cleaned_up_instrs

# %% [markdown]
# ### Silly testing and timing stuff.

# %%
ingr_set2 = set()

for recipe in tqdm(recipes[:200]):
  ingrs = extract_cleaned_ingredients(recipe)
  for ingr in ingrs:
    ingr_set2.add(ingr)

len(ingr_set2)
# Out:
# 100%|██████████| 200/200 [00:48<00:00,  4.12it/s]
# 291

# %%
ingr_set2
# Out:
# {'-half',
#  'allspice',
#  'almond',
#  'almonds',
#  'anchovy paste',
#  'apple',
#  'apples',
#  'avocados',
#  'bacon',
#  'baguette',
#  'bakers',
#  'baking powder',
#  'baking soda',
#  'bananas',
#  'barbecue sauce',
#  'barbeque sauce',
#  'basil',
#  'basil stems removed',
#  'bay leaves',
#  'beans',
#  'beef',
#  'beef broth',
#  'beer',
#  'bell pepper',
#  'bell peppers',
#  'bell peppers roughly',
#  'bite-size',
#  'bits',
#  'blueberries',
#  'boiling',
#  'bouillon',
#  'brand',
#  'bread',
#  'bread mix',
#  'breast',
#  'breasts',
#  'broccoli',
#  'broth',
#  'brownie mix',
#  'buffalo',
#  'bunch',
#  'buns',
#  'butter',
#  'buttermilk',
#  'cabbage',
#  'cake mix',
#  'capers',
#  'carrots',
#  'casings',
#  'cauliflower',
#  'cayenne pepper',
#  'celery',
#  'cheese',
#  'chicken',
#  'chicken breast halves',
#  'chicken breast meat',
#  'chicken broth',
#  'chicken soup',
#  'chickens',
#  'chile peppers',
#  'chile-garlic sauce',
#  'chiles',
#  'chili beans',
#  'chili peppers',
#  'chili powder',
#  'chili sauce',
#  'chilies',
#  'chipotle pepper',
#  'chives',
#  'chocolate',
#  'chocolate chips',
#  'chops',
#  'chuck',
#  'chunks',
#  'cilantro',
#  'cinnamon',
#  'clove',
#  'cloves',
#  'coating',
#  'cocoa powder',
#  'coconut',
#  'cod',
#  'coffee',
#  'coleslaw mix',
#  'condensed cream',
#  'confectioners',
#  'container',
#  'cookie',
#  'cooking',
#  'corn',
#  'corn chips',
#  'cornmeal',
#  'cornstarch',
#  'crabs',
#  'cracker',
#  'crackers',
#  'cranberries',
#  'cream',
#  'crust',
#  'crusts',
#  'cubed',
#  'cubes',
#  'cumin',
#  'dash pepper',
#  'devils',
#  'dew',
#  'dill',
#  'dough',
#  'dressing',
#  'dressing mix',
#  'egg',
#  'eggplant',
#  'eggs',
#  'enchilada sauce',
#  'fillets',
#  'fish sauce',
#  'flakes',
#  'flavor',
#  'florets',
#  'flour',
#  'foil',
#  'food',
#  'fritos',
#  'frosting',
#  'fruit',
#  'garlic',
#  'garlic pepper',
#  'garlic powder',
#  'garnish',
#  'giblets',
#  'ginger',
#  'ginger root',
#  'golden delicious apples',
#  'grain',
#  'granules',
#  'half',
#  'half-and-half cream',
#  'ham',
#  'hearts',
#  'heavy cream',
#  'honey',
#  'hot sauce',
#  'iceberg',
#  'jalapeno pepper',
#  'jalapeno peppers',
#  'jars',
#  'juice',
#  'kernels',
#  'ketchup',
#  'kidney beans',
#  'kiwis',
#  'leaf',
#  'leaves',
#  'lemon',
#  'lemon pepper',
#  'lettuce',
#  'lime',
#  'liqueur',
#  'liquid',
#  'liver',
#  'loaf',
#  'macaroni',
#  'margarine',
#  'marjoram',
#  'mayonnaise',
#  'meat',
#  'meatballs',
#  'milk',
#  'mix together:',
#  'molasses',
#  'mushroom soup',
#  'mushrooms',
#  'mustard',
#  'mustard powder',
#  'noodles',
#  'northern beans',
#  'nutmeg',
#  'oats',
#  'oil',
#  'olive oil',
#  'olives',
#  'onion',
#  'onion powder',
#  'onion soup',
#  'onions',
#  'or pepper',
#  'oregano',
#  'oyster sauce',
#  'packet',
#  'paprika',
#  'parsley',
#  'pasta',
#  'pasta sauce',
#  'pastry',
#  'peaches',
#  'peas',
#  'pecans',
#  'pepper',
#  'pepper sauce',
#  'pie',
#  'pinch',
#  'pinch pepper',
#  'pinches',
#  'pineapple',
#  'pinto beans',
#  'pot roast',
#  'potato',
#  'potato soup',
#  'potatoes',
#  'powder',
#  'pudding mix',
#  'pumpkin',
#  'pumpkin puree',
#  'quinoa',
#  'raisins',
#  'raspberries',
#  'ribs',
#  'rice',
#  'rings',
#  'rolled oats',
#  'rolls',
#  'rosemary',
#  'rump',
#  'sage',
#  'salad',
#  'salmon',
#  'salsa',
#  'salt',
#  'sandwich',
#  'sauce',
#  'sausage',
#  'sausages',
#  'seasoning',
#  'seasoning mix',
#  'seed',
#  'seeds',
#  'serrano pepper',
#  'shallot',
#  'shallots',
#  'sherry',
#  'shortening',
#  'shoulder',
#  'shrimp and',
#  'skewers',
#  'soup mix',
#  'sour cream',
#  'soy sauce',
#  'spaghetti sauce',
#  'spicy sauce',
#  'spinach',
#  'spray',
#  'sprouts',
#  'squash',
#  'steak sauce',
#  'stock',
#  'strawberries',
#  'strips',
#  'style beans',
#  'sugar',
#  'syrup',
#  'taco sauce',
#  'tails',
#  'tamarind paste',
#  'tartar',
#  'tenderloin',
#  'teriyaki',
#  'thighs',
#  'thyme',
#  'tomato',
#  'tomato paste',
#  'tomato sauce',
#  'tomato soup',
#  'tomatoes',
#  'tortilla chips',
#  'tortillas',
#  'vanilla',
#  'vinegar',
#  'wafers',
#  'walnuts',
#  'water',
#  'wedges',
#  'whipped topping',
#  'whipping cream',
#  'wine',
#  'wings',
#  'worcestershire sauce',
#  'wrap',
#  'yeast',
#  'yogurt',
#  'yolk',
#  'zucchini'}

# %%
ingr_set3 = set()

for recipe in tqdm(recipes[:10]):
  ingrs = extract_cleaned_ingredients(recipe)
  for ingr in ingrs:
    ingr_set3.add(ingr)

len(ingr_set3)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 2367.92it/s]
# 52

# %%
IngrProc.cache
# Out:
# {'active yeast': ['yeast'],
#  'allspice': ['allspice'],
#  'almond': ['almond'],
#  'almonds blanched and slivered': ['almonds'],
#  'anchovy paste': ['anchovy paste'],
#  'and cubed butternut squash': ['squash'],
#  'and potatoes': ['potatoes'],
#  'angel hair pasta': ['pasta'],
#  'apples': ['apples'],
#  'apples cored and': ['apples'],
#  'arborio rice': ['rice'],
#  'artichoke hearts and': ['hearts'],
#  'assorted food coloring': ['food'],
#  'avocados - and': ['avocados'],
#  'bacon': ['bacon'],
#  'bacon bits': ['bits'],
#  'bacon in half': ['bacon', 'half'],
#  'bag coleslaw mix': ['coleslaw mix'],
#  'bag corn chips such as fritos®': ['corn chips', 'fritos'],
#  'bakers semi-sweet baking chocolate': ['bakers', 'chocolate'],
#  'baking potatoes': ['potatoes'],
#  'baking powder': ['baking powder'],
#  'baking soda': ['baking soda'],
#  'balsamic syrup': ['syrup'],
#  'balsamic vinegar': ['vinegar'],
#  'bananas': ['bananas'],
#  'basil': ['basil'],
#  'basil leaves': ['leaves'],
#  'basil stems removed': ['basil stems removed'],
#  'bay leaf': ['leaf'],
#  'bay leaves': ['bay leaves'],
#  'beans': ['beans'],
#  'beans and': ['beans'],
#  'beef': ['beef'],
#  'beef broth': ['beef broth'],
#  'beef chuck': ['chuck'],
#  'beef sirloin strips': ['strips'],
#  'beef stew meat cubes': ['cubes'],
#  'beef stock': ['stock'],
#  'beer': ['beer'],
#  'bell pepper': ['bell pepper'],
#  'bell pepper and': ['bell pepper'],
#  'bell peppers': ['bell peppers'],
#  'bell peppers roughly': ['bell peppers roughly'],
#  'biscuit dough torn': ['dough'],
#  'blueberries': ['blueberries'],
#  'boiling water': ['boiling', 'water'],
#  'bottle barbeque sauce': ['barbeque sauce'],
#  'bottle buffalo wing sauce': ['buffalo', 'sauce'],
#  'bottle your favorite barbecue sauce': ['barbecue sauce'],
#  'bow tie pasta': ['pasta'],
#  'box chicken-flavored crackers': ['crackers'],
#  'bread crumbs': ['bread'],
#  'bread flour': ['flour'],
#  'bread machine yeast': ['yeast'],
#  'broccoli': ['broccoli'],
#  'broccoli florets': ['florets'],
#  'broth': ['broth'],
#  'brussels sprouts ends and leaves removed': ['sprouts', 'leaves'],
#  'bulk italian sausage': ['sausage'],
#  'bulk mild italian sausage': ['sausage'],
#  'bunch celery cleaned and': ['celery'],
#  'bunch onions': ['onions'],
#  'bunch spinach tough stems removed': ['bunch'],
#  'butter': ['butter'],
#  'butter cubed': ['butter'],
#  'butter flavored cooking spray': ['butter', 'spray'],
#  'butter flavored shortening': ['butter'],
#  'butter or margarine': ['butter', 'margarine'],
#  'buttermilk': ['buttermilk'],
#  'buttery round cracker crumbs': ['cracker'],
#  'buttery round crackers': ['crackers'],
#  'cajun seasoning': ['seasoning'],
#  'capers': ['capers'],
#  'caraway seeds': ['seeds'],
#  'carrots': ['carrots'],
#  'cauliflower florets': ['florets'],
#  'cayenne pepper': ['cayenne pepper'],
#  'celery': ['celery'],
#  'celery salt': ['salt'],
#  'celery seed': ['seed'],
#  'cheddar cheese': ['cheese'],
#  'chicken': ['chicken'],
#  'chicken bouillon granules': ['granules'],
#  'chicken breast': ['breast'],
#  'chicken breast halves': ['chicken breast halves'],
#  'chicken breast halves - cubes': ['cubes'],
#  'chicken breast halves - pounded thickness': ['chicken'],
#  'chicken breast halves - strips': ['strips'],
#  'chicken breast halves strips': ['strips'],
#  'chicken breast meat': ['chicken breast meat'],
#  'chicken breasts': ['breasts'],
#  'chicken breasts -inch chunks': ['chunks'],
#  'chicken breasts bite-size': ['bite-size'],
#  'chicken broth': ['chicken broth'],
#  'chicken thighs': ['thighs'],
#  'chicken wings': ['wings'],
#  'chile peppers': ['chile peppers'],
#  'chile peppers and': ['chile peppers'],
#  'chile-garlic sauce': ['chile-garlic sauce'],
#  'chiles': ['chiles'],
#  'chili beans': ['chili beans'],
#  'chili beans in spicy sauce': ['chili beans', 'spicy sauce'],
#  'chili peppers': ['chili peppers'],
#  'chili powder': ['chili powder'],
#  'chili seasoning mix': ['seasoning mix'],
#  'chilies': ['chilies'],
#  'chives': ['chives'],
#  'chocolate chips': ['chocolate chips'],
#  'chocolate cookie crumbs': ['cookie'],
#  'chunk chicken': ['chicken'],
#  'cider vinegar': ['vinegar'],
#  'cilantro': ['cilantro'],
#  'cinnamon': ['cinnamon'],
#  'cinnamon sugar': ['sugar'],
#  'clove garlic': ['clove', 'garlic'],
#  'clove garlic and': ['clove', 'garlic'],
#  'clove garlic or': ['clove', 'garlic'],
#  'cloves': ['cloves'],
#  'cloves garlic': ['garlic'],
#  'cocoa powder': ['cocoa powder'],
#  'coconut milk': ['milk'],
#  'cod fillets portions': ['cod'],
#  'colby cheese': ['cheese'],
#  'colby-monterey jack cheese': ['cheese'],
#  'cold milk': ['milk'],
#  'cold water': ['water'],
#  'condensed cream of chicken soup': ['condensed cream', 'chicken soup'],
#  'condensed cream of mushroom soup': ['condensed cream', 'mushroom soup'],
#  'condensed cream of potato soup': ['condensed cream', 'potato soup'],
#  'condensed french onion soup': ['onion soup'],
#  'condensed golden mushroom soup': ['mushroom soup'],
#  'condensed milk': ['milk'],
#  'condensed tomato soup': ['tomato soup'],
#  'confectioners sugar': ['confectioners'],
#  'container alfredo-style pasta sauce': ['pasta sauce'],
#  'container curd cottage cheese': ['cheese'],
#  'container sour cream': ['sour cream'],
#  'container whipped topping': ['container'],
#  'cooking sherry': ['sherry'],
#  'cooking spray': ['spray'],
#  'corn': ['corn'],
#  'corn bread mix': ['bread mix'],
#  'corn kernels': ['kernels'],
#  'corn tortillas': ['tortillas'],
#  'cornmeal': ['cornmeal'],
#  'cornstarch': ['cornstarch'],
#  'cranberries': ['cranberries'],
#  'cream cheese': ['cheese'],
#  'cream cheese with chives': ['cheese', 'chives'],
#  'cream of tartar': ['cream', 'tartar'],
#  'creamed corn': ['corn'],
#  'creamy salad dressing': ['salad'],
#  'crescent roll dough': ['dough'],
#  'crumbled buttery round crackers': ['crackers'],
#  'crunchy peanut butter': ['butter'],
#  'cube beef bouillon': ['bouillon'],
#  'cubed beef stew meat': ['cubed', 'meat'],
#  'cubed bread': ['cubed', 'bread'],
#  'cubed chicken breast meat': ['cubed', 'meat'],
#  'cubed whole wheat bread': ['bread'],
#  'cubes beef bouillon': ['bouillon'],
#  'cubes beef bouillon crumbled': ['bouillon'],
#  'cubes chicken bouillon': ['cubes', 'bouillon'],
#  'cumin': ['cumin'],
#  'curry powder': ['powder'],
#  'dark kidney beans': ['kidney beans'],
#  'dash garlic powder': ['garlic powder'],
#  'dash hot pepper sauce or': ['pepper sauce'],
#  'dash pepper': ['dash pepper'],
#  'day-old bread': ['bread'],
#  'devils food cake mix': ['devils', 'cake mix'],
#  'dijon mustard': ['mustard'],
#  'dill weed': ['dill'],
#  'distilled vinegar': ['vinegar'],
#  'dungeness crabs cleaned and cracked': ['crabs'],
#  'eagle brand® condensed milk': ['brand', 'milk'],
#  'egg': ['egg'],
#  'egg noodles': ['noodles'],
#  'egg yolk': ['yolk'],
#  'eggplant': ['eggplant'],
#  'eggs': ['eggs'],
#  'elbow macaroni': ['macaroni'],
#  'enchilada sauce': ['enchilada sauce'],
#  'envelope onion soup mix': ['soup mix'],
#  'fennel seeds': ['seeds'],
#  'fettuccini pasta': ['pasta'],
#  'fillets salmon': ['salmon'],
#  'fish sauce': ['fish sauce'],
#  'flaked coconut': ['coconut'],
#  'flour': ['flour'],
#  'flour for coating': ['flour', 'coating'],
#  'flour tortillas': ['tortillas'],
#  'flour tortillas warmed': ['tortillas'],
#  'fluid warm water': ['water'],
#  'french baguette': ['baguette'],
#  'french rolls': ['rolls'],
#  'french style beans': ['style beans'],
#  'frosting:': ['frosting'],
#  'fruit preserves any flavor': ['fruit', 'flavor'],
#  'fudge brownie mix': ['brownie mix'],
#  'garlic': ['garlic'],
#  'garlic powder': ['garlic powder'],
#  'garlic salt': ['salt'],
#  'ginger': ['ginger'],
#  'ginger root': ['ginger root'],
#  'golden delicious apple cored and': ['apple'],
#  'golden delicious apples': ['golden delicious apples'],
#  'golden raisins': ['raisins'],
#  'graham cracker crumbs': ['cracker'],
#  'graham cracker crust': ['crust'],
#  'graham crackers': ['crackers'],
#  'granny smith apples - cored and': ['apples'],
#  'granny smith apples and cored': ['apples'],
#  'great northern beans undrained': ['northern beans'],
#  'half-and-half': ['-half'],
#  'half-and-half cream': ['half-and-half cream'],
#  'ham': ['ham'],
#  'hamburger buns split and': ['buns'],
#  'hash potatoes': ['potatoes'],
#  'head cabbage': ['cabbage'],
#  'head cauliflower separated florets': ['cauliflower', 'florets'],
#  'head iceberg lettuce': ['iceberg'],
#  'heavy cream': ['heavy cream'],
#  'heavy whipping cream': ['whipping cream'],
#  'hoagie rolls split lengthwise': ['rolls'],
#  'honey': ['honey'],
#  'hot pepper sauce': ['pepper sauce'],
#  'hot sauce': ['hot sauce'],
#  'hot water': ['water'],
#  'instant chocolate pudding mix': ['pudding mix'],
#  'instant vanilla pudding mix': ['pudding mix'],
#  'irish cream liqueur': ['liqueur'],
#  'italian salad dressing': ['salad'],
#  'italian sausage': ['sausage'],
#  'italian seasoned bread crumbs': ['bread'],
#  'italian seasoning': ['seasoning'],
#  'italian-seasoned bread crumbs': ['bread'],
#  'italian-style plum tomatoes and': ['tomatoes'],
#  'italian-style salad dressing mix': ['dressing mix'],
#  'italian-style seasoned bread crumbs': ['bread'],
#  'italian-style stewed tomatoes': ['tomatoes'],
#  'jalapeno pepper': ['jalapeno pepper'],
#  'jalapeno peppers': ['jalapeno peppers'],
#  'jar salsa': ['salsa'],
#  'jar taco sauce': ['taco sauce'],
#  'jars spaghetti sauce': ['jars', 'sauce'],
#  'ketchup': ['ketchup'],
#  'key lime juice': ['juice'],
#  'kidney beans': ['kidney beans'],
#  'kidney beans and': ['kidney beans'],
#  'kiwis and': ['kiwis'],
#  'kosher salt': ['salt'],
#  'lamb shoulder': ['shoulder'],
#  'lasagna noodles': ['noodles'],
#  'lemon for garnish': ['lemon', 'garnish'],
#  'lemon juice': ['juice'],
#  'lemon pepper': ['lemon pepper'],
#  'lettuce': ['lettuce'],
#  'light corn syrup': ['syrup'],
#  'light kidney beans': ['kidney beans'],
#  'light olive oil': ['olive oil'],
#  'light sugar': ['sugar'],
#  'lime': ['lime'],
#  'lime juice': ['juice'],
#  'lime zest': ['lime'],
#  'linguine pasta': ['pasta'],
#  'little smokie sausages': ['sausages'],
#  'loaf processed cheese food cubed': ['loaf', 'food'],
#  'long-grain rice': ['rice'],
#  'low-fat milk': ['milk'],
#  'mahi mahi fillets': ['fillets'],
#  'maple syrup': ['syrup'],
#  'margarine': ['margarine'],
#  'marjoram': ['marjoram'],
#  'marsala wine': ['wine'],
#  'mayonnaise': ['mayonnaise'],
#  'meatballs': ['meatballs'],
#  'milk': ['milk'],
#  'miniature chocolate covered peanut butter unwrapped': ['chocolate',
#   'butter'],
#  'mix together:': ['mix together:'],
#  'molasses': ['molasses'],
#  'monterey jack cheese': ['cheese'],
#  'mozzarella cheese': ['cheese'],
#  'mozzarella cheese and': ['cheese'],
#  'mushrooms': ['mushrooms'],
#  'mushrooms thinly': ['mushrooms'],
#  'mustard': ['mustard'],
#  'mustard powder': ['mustard powder'],
#  'nutmeg': ['nutmeg'],
#  'oil': ['oil'],
#  'oil for': ['oil'],
#  'oil or as needed': ['oil'],
#  'olive oil': ['olive oil'],
#  'olives': ['olives'],
#  'onion': ['onion'],
#  'onion flakes': ['onion'],
#  'onion powder': ['onion powder'],
#  'onion powder or': ['onion powder'],
#  'onion rings': ['rings'],
#  'onion salt': ['salt'],
#  'onion soup mix': ['soup mix'],
#  'onion thinly': ['onion'],
#  'onion wedges': ['wedges'],
#  'onions': ['onions'],
#  'onions bite-size': ['bite-size'],
#  'or bottle beer': ['beer'],
#  'or bottle mountain dew ™': ['dew'],
#  'or bottle root beer': ['beer'],
#  'or pepper or': ['or pepper'],
#  'oregano': ['oregano'],
#  'oreo chocolate sandwich cookies': ['sandwich'],
#  'overripe bananas': ['bananas'],
#  'oyster sauce': ['oyster sauce'],
#  'palm sugar': ['sugar'],
#  'paprika': ['paprika'],
#  'parmesan cheese': ['cheese'],
#  'parsley': ['parsley'],
#  'parsley flakes': ['parsley'],
#  'parsley for garnish': ['parsley', 'garnish'],
#  'part-skim ricotta cheese': ['cheese'],
#  'peaches - and wedges': ['peaches', 'wedges'],
#  'peanut butter': ['butter'],
#  'peas': ['peas'],
#  'pecans': ['pecans'],
#  'pepper': ['pepper'],
#  'pepper flakes': ['flakes'],
#  'pepper or': ['pepper'],
#  'pepper sauce': ['pepper sauce'],
#  'philadelphia cream cheese': ['cheese'],
#  'pinch cayenne pepper': ['cayenne pepper'],
#  'pinch cayenne pepper or': ['cayenne pepper'],
#  'pinch chipotle pepper': ['chipotle pepper'],
#  'pinch cloves': ['cloves'],
#  'pinch garlic pepper': ['garlic pepper'],
#  'pinch nutmeg': ['pinch', 'nutmeg'],
#  'pinch pepper': ['pinch pepper'],
#  'pinch salt': ['salt'],
#  'pinches cayenne pepper': ['pinches'],
#  'pineapple with juice': ['pineapple', 'juice'],
#  'pinto beans and': ['pinto beans'],
#  'plain yogurt': ['yogurt'],
#  'poppy seeds': ['seeds'],
#  'pork chops': ['chops'],
#  'pork ribs': ['ribs'],
#  'pork tenderloin': ['tenderloin'],
#  'portobello mushrooms thinly': ['mushrooms'],
#  'pot roast': ['pot roast'],
#  'potato flakes': ['potato'],
#  'potatoes': ['potatoes'],
#  'potatoes and cubed': ['potatoes'],
#  'potatoes thinly': ['potatoes'],
#  'provolone cheese': ['cheese'],
#  'pumpkin': ['pumpkin'],
#  'pumpkin puree': ['pumpkin puree'],
#  'quick cooking grain and wild rice with seasoning packet': ['cooking',
#   'grain',
#   'rice',
#   'packet'],
#  'quick cooking oats': ['oats'],
#  'quick-cooking oats': ['oats'],
#  'quinoa': ['quinoa'],
#  'raisins': ['raisins'],
#  'ranch dressing': ['dressing'],
#  'ranch salad dressing mix': ['dressing mix'],
#  'ranch-style salad dressing': ['salad'],
#  'raspberries': ['raspberries'],
#  'recipe pastry for a double crust pie': ['pastry', 'pie'],
#  'reduced-fat cheddar cheese': ['cheese'],
#  'reduced-fat cream cheese cubed and': ['cheese'],
#  'refried beans': ['beans'],
#  'reynolds wrap® non stick aluminum foil': ['wrap', 'foil'],
#  'rice': ['rice'],
#  'ricotta cheese': ['cheese'],
#  'rolled oats': ['rolled oats'],
#  'roma tomatoes': ['tomatoes'],
#  'romano cheese': ['cheese'],
#  'rosemary': ['rosemary'],
#  'rump roast': ['rump'],
#  'russet potatoes': ['potatoes'],
#  'sage': ['sage'],
#  'salmon': ['salmon'],
#  'salmon fillets': ['fillets'],
#  'salsa': ['salsa'],
#  'salt': ['salt'],
#  'salt and pepper': ['salt', 'pepper'],
#  'salt and pepper or': ['salt', 'pepper'],
#  'salt or': ['salt'],
#  'saltine cracker crumbs': ['cracker'],
#  'sauce': ['sauce'],
#  'sauce:': ['sauce'],
#  'sea salt': ['salt'],
#  'seasoned bread crumbs': ['bread'],
#  'seasoned salt': ['salt'],
#  'seasoning salt': ['seasoning', 'salt'],
#  'serrano pepper': ['serrano pepper'],
#  'sesame seeds': ['seeds'],
#  'shallot': ['shallot'],
#  'shallots': ['shallots'],
#  'sharp cheddar cheese': ['cheese'],
#  'shortening': ['shortening'],
#  'shrimp and': ['shrimp and'],
#  'shrimp tails removed': ['tails'],
#  'skewers': ['skewers'],
#  'skim milk': ['milk'],
#  'sour cream': ['sour cream'],
#  'soy sauce': ['soy sauce'],
#  'spaghetti sauce': ['spaghetti sauce'],
#  'spinach': ['spinach'],
#  'spinach - and torn': ['spinach'],
#  'spinach - and torn bite-size': ['bite-size'],
#  'spinach and': ['spinach'],
#  'spinach and torn bite-size': ['spinach', 'bite-size'],
#  'stalk celery': ['celery'],
#  'stalk celery leaves removed': ['leaves'],
#  'stalks celery': ['celery'],
#  'steak sauce': ['steak sauce'],
#  'stewed tomatoes': ['tomatoes'],
#  'stewed tomatoes with liquid': ['tomatoes', 'liquid'],
#  'strawberries': ['strawberries'],
#  'strong brewed coffee': ['coffee'],
#  'sugar': ['sugar'],
#  'sugar or': ['sugar'],
#  'sun-dried tomatoes': ['tomatoes'],
#  'sun-dried tomatoes in oil': ['tomatoes', 'oil'],
#  'sweet italian sausage': ['sausage'],
#  'sweet italian sausage casings removed and crumbled': ['casings'],
#  'sweet potato': ['potato'],
#  'sweet potato cubed': ['potato'],
#  'sweet potatoes': ['potatoes'],
#  'swiss cheese': ['cheese'],
#  'taco seasoning': ['seasoning'],
#  'taco seasoning mix': ['seasoning mix'],
#  'tamarind paste': ['tamarind paste'],
#  'teriyaki basting sauce': ['teriyaki', 'sauce'],
#  'thai chili sauce or hot sauce': ['chili sauce', 'hot sauce'],
#  'thick bread': ['bread'],
#  'thickly bacon': ['bacon'],
#  'thinly onion': ['onion'],
#  'thyme': ['thyme'],
#  'tilapia fillets': ['fillets'],
#  'tomato': ['tomato'],
#  'tomato juice': ['juice'],
#  'tomato paste': ['tomato paste'],
#  'tomato sauce': ['tomato sauce'],
#  'tomatoes': ['tomatoes'],
#  'tomatoes with chile peppers': ['tomatoes', 'chile peppers'],
#  'tomatoes with chilies undrained': ['tomatoes', 'chilies'],
#  'tomatoes with juice': ['tomatoes', 'juice'],
#  'tortilla chips': ['tortilla chips'],
#  'turkey liver': ['liver'],
#  'turkey sausage': ['sausage'],
#  'turkey stock': ['stock'],
#  'unbaked pie crust': ['crust'],
#  'unbaked pie crusts': ['crusts'],
#  'unsalted butter': ['butter'],
#  'unsalted butter and': ['butter'],
#  'vanilla': ['vanilla'],
#  'vanilla wafers': ['wafers'],
#  'very ripe bananas': ['bananas'],
#  'vinegar': ['vinegar'],
#  'walnuts': ['walnuts'],
#  'warm milk': ['milk'],
#  'warm water': ['water'],
#  'water': ['water'],
#  'water as needed': ['water'],
#  'whipped topping': ['whipped topping'],
#  'whole chicken breasts': ['breasts'],
#  'whole chicken giblets removed': ['giblets'],
#  'whole chickens': ['chickens'],
#  'whole kernel corn': ['corn'],
#  'whole mushrooms': ['mushrooms'],
#  'whole tomatoes': ['tomatoes'],
#  'whole wheat rotini pasta': ['pasta'],
#  'wine': ['wine'],
#  'wine vinegar': ['vinegar'],
#  'worcestershire sauce': ['worcestershire sauce'],
#  'yogurt': ['yogurt'],
#  'ziti pasta': ['pasta'],
#  'zucchini': ['zucchini'],
#  'zucchini cubed': ['zucchini']}

# %%
ingr_set = set()
for recipe in tqdm(recipes):
  title, ingrs, instrs = process_recipe(recipe)
  for ingr in ingrs:
    ingr_set.add(ingr)

len(ingr_set)
# Out:
# 100%|██████████| 100/100 [02:02<00:00,  1.22s/it]
# 215

# %%
ingr_set

# %% [markdown]
# # Practice
#
# Apply the processing to all of the recipes

# %%
tiny_recipes = recipes[300:1000]

# %%
tiny_recipes
# Out:
# 302     🍴 Slow Cooker Texas Pulled Pork\n\n🥑\n• 1 teas...
# 303     🍴 Yellow Squash Casserole\n\n🥑\n• 4 cups slice...
# 304     🍴 Simple Turkey Chili\n\n🥑\n• 1 1/2 teaspoons ...
# 305     🍴 Creamy Chocolate Frosting\n\n🥑\n• 2 3/4 cups...
# 306     🍴 Orzo with Parmesan and Basil\n\n🥑\n• 2 table...
#                               ...
# 1001    🍴 Chicken Wing Dip\n\n🥑\n• 2 (8 ounce) package...
# 1002    🍴 Black Bean Brownies\n\n🥑\n• 1 (15.5 ounce) c...
# 1003    🍴 Salmon with Brown Sugar Glaze\n\n🥑\n• 1/4 cu...
# 1004    🍴 Strawberry Angel Food Dessert\n\n🥑\n• 1 (10 ...
# 1005    🍴 Pineapple Chicken Tenders\n\n🥑\n• 1 cup pine...
# Length: 700, dtype: object

# %%
df_tiny_recipes = pd.DataFrame({'recipe': tiny_recipes})

# %%
df_tiny_recipes.apply(lambda row: process_recipe(row['recipe']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-20c05a771943> in <module>()
# ----> 1 df_tiny_recipes.apply(lambda row: process_recipe(row['recipe']), axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7550             kwds=kwds,
#    7551         )
# -> 7552         return op.get_result()
#    7553
#    7554     def applymap(self, func) -> "DataFrame":
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     303                 for i, v in enumerate(series_gen):
#     304                     # ignore SettingWithCopy here in case the user mutates
# --> 305                     results[i] = self.f(v)
#     306                     if isinstance(results[i], ABCSeries):
#     307                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-81-20c05a771943> in <lambda>(row)
# ----> 1 df_tiny_recipes.apply(lambda row: process_recipe(row['recipe']), axis=1)
#
# <ipython-input-76-e65a96906c9c> in process_recipe(recipe)
#      15   ingredients = ingredients.replace('\n', '').split("•")
#      16   ingredients = [ingredient.strip() for ingredient in ingredients if len(ingredient) > 0]
# ---> 17   cleaned_up_ingrs = flatten([IngrProc.cleanup_ingredient(ingredient) for ingredient in ingredients])
#      18
#      19   # Process instructions
#
# <ipython-input-76-e65a96906c9c> in <listcomp>(.0)
#      15   ingredients = ingredients.replace('\n', '').split("•")
#      16   ingredients = [ingredient.strip() for ingredient in ingredients if len(ingredient) > 0]
# ---> 17   cleaned_up_ingrs = flatten([IngrProc.cleanup_ingredient(ingredient) for ingredient in ingredients])
#      18
#      19   # Process instructions
#
# <ipython-input-75-30cd724e950f> in cleanup_ingredient(self, ingredient)
#      79
#      80     # Apply spacy to get the most important noun phrase (hopefully)
# ---> 81     ingr_doc = self.nlp(ingredient)
#      82     noun_phrases = [chunk.text for chunk in ingr_doc.noun_chunks]
#      83
#
# /usr/local/lib/python3.7/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     429                 Errors.E088.format(length=len(text), max_length=self.max_length)
#     430             )
# --> 431         doc = self.make_doc(text)
#     432         if component_cfg is None:
#     433             component_cfg = {}
#
# /usr/local/lib/python3.7/dist-packages/spacy/language.py in make_doc(self, text)
#     455
#     456     def make_doc(self, text):
# --> 457         return self.tokenizer(text)
#     458
#     459     def _format_docs_and_golds(self, docs, golds):
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.__call__()
#
# doc.pyx in spacy.tokens.doc.Doc.__init__()
#
# doc.pyx in spacy.tokens.doc._get_chunker()
#
# /usr/local/lib/python3.7/dist-packages/spacy/util.py in get_lang_class(lang)
#      68     """
#      69     # Check if language is registered / entry point is available
# ---> 70     if lang in registry.languages:
#      71         return registry.languages.get(lang)
#      72     else:
#
# /usr/local/lib/python3.7/dist-packages/catalogue.py in __contains__(self, name)
#      54         """
#      55         namespace = tuple(list(self.namespace) + [name])
# ---> 56         has_entry_point = self.entry_points and self.get_entry_point(name)
#      57         return has_entry_point or namespace in REGISTRY
#      58
#
# /usr/local/lib/python3.7/dist-packages/catalogue.py in get_entry_point(self, name, default)
#     136         RETURNS (Any): The loaded entry point or the default value.
#     137         """
# --> 138         for entry_point in AVAILABLE_ENTRY_POINTS.get(self.entry_point_namespace, []):
#     139             if entry_point.name == name:
#     140                 return entry_point.load()
#
# /usr/local/lib/python3.7/dist-packages/importlib_metadata/__init__.py in get(self, name, default)
#     309
#     310     def get(self, name, default=None):
# --> 311         flake8_bypass(self._warn)()
#     312         return super().get(name, default)
#     313
#
# /usr/local/lib/python3.7/dist-packages/importlib_metadata/__init__.py in flake8_bypass(func)
#     270     import inspect
#     271
# --> 272     is_flake8 = any('flake8' in str(frame.filename) for frame in inspect.stack()[:5])
#     273     return func if not is_flake8 else lambda: None
#     274
#
# /usr/lib/python3.7/inspect.py in stack(context)
#    1511 def stack(context=1):
#    1512     """Return a list of records for the stack above the caller's frame."""
# -> 1513     return getouterframes(sys._getframe(1), context)
#    1514
#    1515 def trace(context=1):
#
# /usr/lib/python3.7/inspect.py in getouterframes(frame, context)
#    1488     framelist = []
#    1489     while frame:
# -> 1490         frameinfo = (frame,) + getframeinfo(frame, context)
#    1491         framelist.append(FrameInfo(*frameinfo))
#    1492         frame = frame.f_back
#
# /usr/lib/python3.7/inspect.py in getframeinfo(frame, context)
#    1462         start = lineno - 1 - context//2
#    1463         try:
# -> 1464             lines, lnum = findsource(frame)
#    1465         except OSError:
#    1466             lines = index = None
#
# /usr/lib/python3.7/inspect.py in findsource(object)
#     766     is raised if the source code cannot be retrieved."""
#     767
# --> 768     file = getsourcefile(object)
#     769     if file:
#     770         # Invalidate cache if needed.
#
# /usr/lib/python3.7/inspect.py in getsourcefile(object)
#     694         return filename
#     695     # only return a non-existent filename if the module has a PEP 302 loader
# --> 696     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#     697         return filename
#     698     # or it is in the linecache
#
# /usr/lib/python3.7/inspect.py in getmodule(object, _filename)
#     731     # Copy sys.modules in order to cope with changes while iterating
#     732     for modname, module in sys.modules.copy().items():
# --> 733         if ismodule(module) and hasattr(module, '__file__'):
#     734             f = module.__file__
#     735             if f == _filesbymodname.get(modname, None):
#
# KeyboardInterrupt:

# %%
shj = _

# %%
df_tiny_recipes['title'] = df_tiny_recipes.apply(lambda row: extract_title(row['recipe']), axis=1)

# %%
df_tiny_recipes['ingredients'] = df_tiny_recipes.apply(lambda row: extract_cleaned_ingredients(row['recipe']), axis=1)

# %%
df_tiny_recipes['instructions'] = df_tiny_recipes.apply(lambda row: extract_cleaned_instructions(row['recipe']), axis=1)

# %%
df_tiny_recipes
# Out:
#                                                  recipe
# 302   🍴 Slow Cooker Texas Pulled Pork\n\n🥑\n• 1 teas...
# 303   🍴 Yellow Squash Casserole\n\n🥑\n• 4 cups slice...
# 304   🍴 Simple Turkey Chili\n\n🥑\n• 1 1/2 teaspoons ...
# 305   🍴 Creamy Chocolate Frosting\n\n🥑\n• 2 3/4 cups...
# 306   🍴 Orzo with Parmesan and Basil\n\n🥑\n• 2 table...
# ...                                                 ...
# 1001  🍴 Chicken Wing Dip\n\n🥑\n• 2 (8 ounce) package...
# 1002  🍴 Black Bean Brownies\n\n🥑\n• 1 (15.5 ounce) c...
# 1003  🍴 Salmon with Brown Sugar Glaze\n\n🥑\n• 1/4 cu...
# 1004  🍴 Strawberry Angel Food Dessert\n\n🥑\n• 1 (10 ...
# 1005  🍴 Pineapple Chicken Tenders\n\n🥑\n• 1 cup pine...
#
# [700 rows x 1 columns]

# %%
dataset_path = os.path.join(CACHE_DIR, 'tiny_cleaned_recipes.pkl')
df_tiny_recipes.to_pickle(dataset_path)

# %%
df_tiny_recipes_unpickled = pd.read_pickle(dataset_path)

# %%
df_tiny_recipes['ingredients'] = df_tiny_recipes.progress_apply(lambda row: extract_cleaned_ingredients(row['recipe']), axis=1)
# Out:
# 100%|██████████| 700/700 [02:32<00:00,  4.59it/s]

# %% [markdown]
# # Now actually process all the recipes
#
# Or at least the first 20000

# %%
df_recipes = pd.DataFrame({'recipe': recipes})

# %%
len(df_recipes)
# Out:
# 105789

# %%
# Process all of the recipes.

print("Extracting titles")
df_recipes['title'] = df_recipes.progress_apply(lambda row: extract_title(row['recipe']), axis=1)
print("Extracting and processing ingredients")
df_recipes['ingredients'] = df_recipes.progress_apply(lambda row: extract_cleaned_ingredients(row['recipe']), axis=1)
print("Extracting instructions")
df_recipes['instructions'] = df_recipes.progress_apply(lambda row: extract_cleaned_instructions(row['recipe']), axis=1)

df_recipe_dataset_path = os.path.join(CACHE_DIR, 'ingr_cleaned_recipes_20210525.pkl')
df_recipes.to_pickle(df_recipe_dataset_path)

ingr_proc_dataset_path = os.path.join(CACHE_DIR, 'ingr_proc_20210525.pkl')
with open(ingr_proc_dataset_path, "wb") as ingr_proc_fn:
  pickle.dump(IngrProc, ingr_proc_fn)
# Out:
#   4%|▍         | 4206/105789 [00:00<00:02, 42055.43it/s]
# Extracting titles
# 100%|██████████| 105789/105789 [00:02<00:00, 35585.55it/s]
#   0%|          | 0/105789 [00:00<?, ?it/s]
# Extracting and processing ingredients
# 100%|██████████| 105789/105789 [4:37:11<00:00,  6.36it/s]
#   0%|          | 1/105789 [00:00<3:46:54,  7.77it/s]
# Extracting instructions
# 100%|██████████| 105789/105789 [00:03<00:00, 27168.06it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0ec65e35b67c> in <module>()
#       9
#      10 df_recipe_dataset_path = os.path.join(CACHE_DIR, 'ingr_cleaned_recipes_20210524.pkl')
# ---> 11 df_tiny_recipes.to_pickle(df_recipe_dataset_path)
#      12
#      13 ingr_proc_dataset_path = os.path.join(CACHE_DIR, 'ingr_proc_20210524.pkl')
#
# NameError: name 'df_tiny_recipes' is not defined

# %%
# df_recipe_dataset_path = os.path.join(CACHE_DIR, 'ingr_cleaned_recipes_20210525.pkl')
# df_recipes.to_pickle(df_recipe_dataset_path)

# ingr_proc_dataset_path = os.path.join(CACHE_DIR, 'ingr_proc_20210525.pkl')
# with open(ingr_proc_dataset_path, "wb") as ingr_proc_fn:
#   pickle.dump(IngrProc, ingr_proc_fn)
